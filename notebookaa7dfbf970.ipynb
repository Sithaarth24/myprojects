# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('/kaggle/input/salary-data-prediction/Salary_Data.csv')
print(data)

# %%
plt.scatter(data.YearsExperience,data.Salary)
plt.show()

# %%
def Gradient_descent(om,ob,points):
    mgrad = 0
    bgrad = 0
    for i in points:
        x=i[0]
        y=i[1]
        mgrad += -x*(y-(om*x + ob))
        bgrad += -(y-(om*x + ob))

# %%
arr = np.array(data)
Gradient_descent(0,0,arr)

# %%
arr = np.array(data)
